// %% [markdown]
// ## Problems related to open-source Darknet repository
// 1. Which factor is **dominant** in the uncertainty of CNN object detection applications? The **inherent inaccuracy** of Neural Network or the degradation caused by **faults** in the computing hardware.
//
//
// 2. Extract feature maps in a reasonable way to model **fault propagation**.
//
//
// 3. Pure Technical Questions: Fit Darknet into NVBitFI

// %% [markdown]
// ## A. Train Darknet for Kitti
// To study RQ1, one possible way is also considering the accuray of an CNN application. In addition to traditional "golden ref" vs "fault injected DUT" comparison, the mean Average Precision (mAPs) of "golden ref", "faulty" should also be measured.
//
// Additionaly, to emphasize the primary concern of this study is autonomous driving senarios. Darknet is trained for Kitti 2D object detection dataset
//
// This section introduces how to train Darknet for KITTI step by step.
//
// **Note** : Unless otherwise specified, the parent directory of this notebook is ```darknet/```

// %% [markdown]
// ### 0. Get KITTI 2d object detection dataset
// Register and download the evaluation datsets at: http://www.cvlibs.net/datasets/kitti/eval_object.php

// %% [markdown]
// ### a. Convert KITTI labels to YOLO style

// %% [markdown]
// KITTI label format looks like:
//
// ```Pedestrian 0.00 0 -0.20 712.40 143.00 810.73 307.92 1.89 0.48 1.20 1.84 1.47 8.41 0.01```
//
// YOLO label format is:
//
// ```4 0.622 0.609 0.08 0.446```
//
// Luckily, there are several handy open source tools can help do this: https://github.com/ssaru/convert2Yolo

// %% [markdown]
// The steps of label conversion is straight forward, the only user-defined file is ```.name```, in which users should type in concerned class names.
//
// Then users just need to run python script with necessary arguments, the rest will be handled by convert2Yolo tool

// %% [markdown]
// ### b. Network configuration, training/validation datasets preparation

// %% [markdown]
// Following the instructions of AlexDarknet https://github.com/AlexeyAB/darknet, and valuable discussion of how to train YOLO with KITTI more accurately http://yizhouwang.net/blog/2018/07/29/train-yolov2-kitti/. I sucessfully got everything right and trained YOLOv3, obtained a weights file specifically for KITTI dataset.

// %% [markdown]
// 1. Prepare your own configuration (```.cfg```) file, which defines the size of network, several tweakable hyper-parameters. Depending how many classes are concerned in **(a)**, the number of classes, and the filter size before each yolo layer should be adjusted accordingly.
//
//
// 2. Create ```.data``` and ```.name``` file in directory ```data/```

// %% [markdown]
// ***Example of ```.data``` file***
//
// ```classes = 6
// train  = data/train.txt
// valid  = data/test.txt
// names = data/kitti.names
// backup = backup/```
//
// ***Example of ```.name``` file***
//
// ```Car
//  Van
//  Truck
//  Tram
//  Pedestrian
//  Cyclist```

// %% [markdown]
// 3. Put ```image-file``` and ```label-files``` obtained through **(a)** into directories: ```data/training``` and ```data/testing```

// %% [markdown]
// 4. Use handy script ```traingen.py``` to create ```train.txt``` and ```test.txt```, put these files in  ```data/``` directory

// %% [markdown]
// 5. Prepare pre-trained ```weights-file```. Training will start from a pretrained weights file, I guess the pretrained weights serves as a good start point for the transfer learning
//
//
// 6. Start Training using the command below

// %%
!./darknet detector train data/kitti.data cfg/yolov3-kitti.cfg yolov3-kitti_last.weights

// %% [markdown]
// Like most CNN training, training yolov3 is time consuming even for newer GPUs, I stopped training after approximately 6 hours, with a loss of 0.8

// %% [markdown]
// ### c. Evaluate the accuray of the trained model

// %% [markdown]
// #### 1. Test the YOLOv3 weights we trained for KITTI

// %% [markdown]
// KITTI dataset is splitted into the training set and the validation set. Training set contains the first **5001 images**, and the validation set contains the rest **(2480 images)**.

// %%
!./darknet detector map data/kitti.data cfg/yolov3-kitti.cfg yolov3-kitti_last.weights -iou_thresh 0.25
// Out:
//  CUDA-version: 11040 (11040), cuDNN: 8.3.1, GPU count: 1
//  OpenCV version: 4.2.0
//  0 : compute_capability = 860, cudnn_half = 0, GPU: NVIDIA GeForce RTX 3070 Ti
//    layer   filters  size/strd(dil)      input                output
//    0 conv     32       3 x 3/ 1    256 x1216 x   3 ->  256 x1216 x  32 0.538 BF
//    1 conv     64       3 x 3/ 2    256 x1216 x  32 ->  128 x 608 x  64 2.869 BF
//    2 conv     32       1 x 1/ 1    128 x 608 x  64 ->  128 x 608 x  32 0.319 BF
//    3 conv     64       3 x 3/ 1    128 x 608 x  32 ->  128 x 608 x  64 2.869 BF
//    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 128 x 608 x  64 0.005 BF
//    5 conv    128       3 x 3/ 2    128 x 608 x  64 ->   64 x 304 x 128 2.869 BF
//    6 conv     64       1 x 1/ 1     64 x 304 x 128 ->   64 x 304 x  64 0.319 BF
//    7 conv    128       3 x 3/ 1     64 x 304 x  64 ->   64 x 304 x 128 2.869 BF
//    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs:  64 x 304 x 128 0.002 BF
//    9 conv     64       1 x 1/ 1     64 x 304 x 128 ->   64 x 304 x  64 0.319 BF
//   10 conv    128       3 x 3/ 1     64 x 304 x  64 ->   64 x 304 x 128 2.869 BF
//   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs:  64 x 304 x 128 0.002 BF
//   12 conv    256       3 x 3/ 2     64 x 304 x 128 ->   32 x 152 x 256 2.869 BF
//   13 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   14 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   16 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   17 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   19 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   20 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   22 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   23 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   25 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   26 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   28 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   29 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   31 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   32 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   34 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   35 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   37 conv    512       3 x 3/ 2     32 x 152 x 256 ->   16 x  76 x 512 2.869 BF
//   38 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   39 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   41 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   42 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   44 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   45 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   47 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   48 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   50 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   51 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   53 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   54 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   56 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   57 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   59 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   60 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   62 conv   1024       3 x 3/ 2     16 x  76 x 512 ->    8 x  38 x1024 2.869 BF
//   63 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   64 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   66 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   67 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   69 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   70 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   72 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   73 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   75 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   76 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   77 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   78 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   79 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   80 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   81 conv     33       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x  33 0.021 BF
//   82 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
//   83 route  79 		                           ->    8 x  38 x 512
//   84 conv    256       1 x 1/ 1      8 x  38 x 512 ->    8 x  38 x 256 0.080 BF
//   85 upsample                 2x     8 x  38 x 256 ->   16 x  76 x 256
//   86 route  85 61 	                           ->   16 x  76 x 768
//   87 conv    256       1 x 1/ 1     16 x  76 x 768 ->   16 x  76 x 256 0.478 BF
//   88 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   89 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   90 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   91 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   92 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   93 conv     33       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x  33 0.041 BF
//   94 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
//   95 route  91 		                           ->   16 x  76 x 256
//   96 conv    128       1 x 1/ 1     16 x  76 x 256 ->   16 x  76 x 128 0.080 BF
//   97 upsample                 2x    16 x  76 x 128 ->   32 x 152 x 128
//   98 route  97 36 	                           ->   32 x 152 x 384
//   99 conv    128       1 x 1/ 1     32 x 152 x 384 ->   32 x 152 x 128 0.478 BF
//  100 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//  101 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//  102 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//  103 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//  104 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//  105 conv     33       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x  33 0.082 BF
//  106 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
// Total BFLOPS 117.536
// avg_outputs = 931279
//  Allocate additional workspace_size = 59.84 MB
// Loading weights from yolov3-kitti_last.weights...net.optimized_memory = 0
// mini_batch = 1, batch = 64, time_steps = 1, train = 0
// Create CUDA-stream - 0
//  Create cudnn-handle 0
// Done! Loaded 107 layers from weights-file
// 2480
//  seen 64, trained: 448 K-images (7 Kilo-batches_64)
//
//  calculation mAP (mean average precision)...
//  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
//
//  detections_count = 23495, unique_truth_count = 12438
// class_id = 0, name = Car, ap = 91.49%   	 (TP = 7592, FP = 583)
// class_id = 1, name = Van, ap = 85.19%   	 (TP = 679, FP = 143)
// class_id = 2, name = Truck, ap = 94.30%   	 (TP = 287, FP = 13)
// class_id = 3, name = Tram, ap = 87.09%   	 (TP = 116, FP = 13)
// class_id = 4, name = Pedestrian, ap = 49.28%   	 (TP = 474, FP = 170)
// class_id = 5, name = Cyclist, ap = 63.27%   	 (TP = 255, FP = 85)
//
//  for conf_thresh = 0.25, precision = 0.90, recall = 0.76, F1-score = 0.82
//  for conf_thresh = 0.25, TP = 9403, FP = 1007, FN = Total Detection Time: 34 Seconds
// 3035, average IoU = 67.93 %
//
//  IoU threshold = 25 %, used Area-Under-Curve for each unique Recall
//  mean average precision (mAP@0.25) = 0.784355, or 78.44 %
//
// Set -points flag:
//  `-points 101` for MS COCO
//  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
//  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

// %% [markdown]
// Dectection mAP at IOU=0.25
//
// ```
// class_id = 0, name = Car, ap = 91.49%   	 (TP = 7592, FP = 583)
// class_id = 1, name = Van, ap = 85.19%   	 (TP = 679, FP = 143)
// class_id = 2, name = Truck, ap = 94.30%   	 (TP = 287, FP = 13)
// class_id = 3, name = Tram, ap = 87.09%   	 (TP = 116, FP = 13)
// class_id = 4, name = Pedestrian, ap = 49.28%   	 (TP = 474, FP = 170)
// class_id = 5, name = Cyclist, ap = 63.27%   	 (TP = 255, FP = 85)
// ```

// %% [markdown]
// As shown above, the retrained model performs well in recoginizing vehicles but its performance is worse regarding pedestrians and cyclists.

// %% [markdown]
// #### 2. Test other pre-trained YOLOv3 weights with the KITTI dataset

// %% [markdown]
// One possible way to test other pre-trained model is setting the concerned classes names to be consistent with KITTI labels. All other labels are considered "don't care". For example, we can compute mAP with default weights provided in Darknet Repo:

// %%
!./darknet detector map data/kitti_coco.data cfg/yolov3.cfg weights/yolov3.weights -iou_thresh 0.25
// Out:
//  CUDA-version: 11040 (11040), cuDNN: 8.3.1, GPU count: 1
//  OpenCV version: 4.2.0
//  0 : compute_capability = 860, cudnn_half = 0, GPU: NVIDIA GeForce RTX 3070 Ti
//    layer   filters  size/strd(dil)      input                output
//    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
//    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
//    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
//    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
//    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
//    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
//    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
//    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
//    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
//    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
//   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
//   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
//   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
//   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
//   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
//   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
//   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
//   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
//   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
//   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
//   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
//   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
//   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
//   81 conv    255       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 255 0.088 BF
//   82 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
//   83 route  79 		                           ->   13 x  13 x 512
//   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
//   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
//   86 route  85 61 	                           ->   26 x  26 x 768
//   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
//   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
//   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
//   93 conv    255       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 255 0.177 BF
//   94 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
//   95 route  91 		                           ->   26 x  26 x 256
//   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
//   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
//   98 route  97 36 	                           ->   52 x  52 x 384
//   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
//  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
//  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
//  105 conv    255       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 255 0.353 BF
//  106 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
// Total BFLOPS 65.879
// avg_outputs = 532444
//  Allocate additional workspace_size = 33.30 MB
// Loading weights from weights/yolov3.weights...net.optimized_memory = 0
// mini_batch = 1, batch = 1, time_steps = 1, train = 0
// Create CUDA-stream - 0
//  Create cudnn-handle 0
// Done! Loaded 107 layers from weights-file
// 2480
//  seen 64, trained: 32013 K-images (500 Kilo-batches_64)
//
//  calculation mAP (mean average precision)...
//  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
//
//  detections_count = 129101, unique_truth_count = 12438
// class_id = 0, name = Car, ap = 0.51%   	 (TP = 24, FP = 1230)
// class_id = 1, name = Van, ap = 0.00%   	 (TP = 0, FP = 451)
// class_id = 2, name = Truck, ap = 0.22%   	 (TP = 13, FP = 11640)
// class_id = 3, name = Tram, ap = 0.00%   	 (TP = 0, FP = 48)
// class_id = 4, name = Pedestrian, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 5, name = Cyclist, ap = 0.00%   	 (TP = 0, FP = 312)
// class_id = 6, name = Tram, ap = 0.00%   	 (TP = 0, FP = 191)
// class_id = 7, name = Truck, ap = 0.00%   	 (TP = 0, FP = 1497)
// class_id = 8, name = boat, ap = 0.00%   	 (TP = 0, FP = 14)
// class_id = 9, name = traffic light, ap = 0.00%   	 (TP = 0, FP = 603)
// class_id = 10, name = fire hydrant, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 11, name = stop sign, ap = 0.00%   	 (TP = 0, FP = 57)
// class_id = 12, name = parking meter, ap = 0.00%   	 (TP = 0, FP = 23)
// class_id = 13, name = bench, ap = 0.00%   	 (TP = 0, FP = 6)
// class_id = 14, name = bird, ap = 0.00%   	 (TP = 0, FP = 3)
// class_id = 15, name = cat, ap = 0.00%   	 (TP = 0, FP = 2)
// class_id = 16, name = dog, ap = 0.00%   	 (TP = 0, FP = 5)
// class_id = 17, name = horse, ap = 0.00%   	 (TP = 0, FP = 5)
// class_id = 18, name = sheep, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 19, name = cow, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 20, name = elephant, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 21, name = bear, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 22, name = zebra, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 23, name = giraffe, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 24, name = backpack, ap = 0.00%   	 (TP = 0, FP = 11)
// class_id = 25, name = umbrella, ap = 0.00%   	 (TP = 0, FP = 7)
// class_id = 26, name = handbag, ap = 0.00%   	 (TP = 0, FP = 18)
// class_id = 27, name = tie, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 28, name = suitcase, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 29, name = frisbee, ap = 0.00%   	 (TP = 0, FP = 1)
// class_id = 30, name = skis, ap = 0.00%   	 (TP = 0, FP = 0)
// claTotal Detection Time: 22 Seconds
// ss_id = 31, name = snowboard, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 32, name = sports ball, ap = 0.00%   	 (TP = 0, FP = 2)
// class_id = 33, name = kite, ap = 0.00%   	 (TP = 0, FP = 3)
// class_id = 34, name = baseball bat, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 35, name = baseball glove, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 36, name = skateboard, ap = 0.00%   	 (TP = 0, FP = 9)
// class_id = 37, name = surfboard, ap = 0.00%   	 (TP = 0, FP = 2)
// class_id = 38, name = tennis racket, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 39, name = bottle, ap = 0.00%   	 (TP = 0, FP = 1)
// class_id = 40, name = wine glass, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 41, name = cup, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 42, name = fork, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 43, name = knife, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 44, name = spoon, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 45, name = bowl, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 46, name = banana, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 47, name = apple, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 48, name = sandwich, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 49, name = orange, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 50, name = broccoli, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 51, name = carrot, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 52, name = hot dog, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 53, name = pizza, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 54, name = donut, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 55, name = cake, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 56, name = chair, ap = 0.00%   	 (TP = 0, FP = 60)
// class_id = 57, name = sofa, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 58, name = pottedplant, ap = 0.00%   	 (TP = 0, FP = 18)
// class_id = 59, name = bed, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 60, name = diningtable, ap = 0.00%   	 (TP = 0, FP = 11)
// class_id = 61, name = toilet, ap = 0.00%   	 (TP = 0, FP = 2)
// class_id = 62, name = tvmonitor, ap = 0.00%   	 (TP = 0, FP = 1)
// class_id = 63, name = laptop, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 64, name = mouse, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 65, name = remote, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 66, name = keyboard, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 67, name = cell phone, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 68, name = microwave, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 69, name = oven, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 70, name = toaster, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 71, name = sink, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 72, name = refrigerator, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 73, name = book, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 74, name = clock, ap = 0.00%   	 (TP = 0, FP = 2)
// class_id = 75, name = vase, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 76, name = scissors, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 77, name = teddy bear, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 78, name = hair drier, ap = 0.00%   	 (TP = 0, FP = 0)
// class_id = 79, name = toothbrush, ap = 0.00%   	 (TP = 0, FP = 0)
//
//  for conf_thresh = 0.25, precision = 0.00, recall = 0.00, F1-score = 0.00
//  for conf_thresh = 0.25, TP = 37, FP = 16235, FN = 12401, average IoU = 0.11 %
//
//  IoU threshold = 25 %, used Area-Under-Curve for each unique Recall
//  mean average precision (mAP@0.25) = 0.000092, or 0.01 %
//
// Set -points flag:
//  `-points 101` for MS COCO
//  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
//  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

// %% [markdown]
// ```
// class_id = 0, name = Pedestrian, ap = 0.51%   	 (TP = 24, FP = 1230)
// class_id = 1, name = Cyclist, ap = 0.00%   	 (TP = 0, FP = 451)
// class_id = 2, name = Car, ap = 0.22%   	 (TP = 13, FP = 11640)
// class_id = 3, name = Cyclist, ap = 0.00%   	 (TP = 0, FP = 48)
// class_id = 5, name = Van, ap = 0.00%   	 (TP = 0, FP = 312)
// class_id = 6, name = Tram, ap = 0.00%   	 (TP = 0, FP = 191)
// class_id = 7, name = Truck, ap = 0.00%   	 (TP = 0, FP = 1497)
// ```

// %% [markdown]
// The performance of pre-trained weight is horrible, let's try yolov4:

// %%
!./darknet detector map data/kitti_coco.data cfg/yolov4.cfg weights/yolov4.weights -iou_thresh 0.01

// %% [markdown]
// It is still horrible, further adjustments may be required

// %% [markdown]
// ### d. Summary of retraining and accuracy evaluation
// Comparing with previous studies by Prof. Paolo Rech's team, the **inherent accuracy of YOLOv3 detector** is emphasized. YOLOv3 is **retrained** for the **KITTI 2d object dataset** and achieved an acceptable accuracy.
//
//
// Further experiment will be conducted to compare the mAP of YOLOv3 application under different setups **fault injected** with **golden ref**. The anticipated results should be mAP response to hardware faults.

// %% [markdown]
// ## B. Extract Feature Map

// %% [markdown]
// ### a. Extract feature map when using GPU
// #### 1. Extract in a fast way, extract each layer's average
// Uncomment the following lines within the function ```forward_network_gpu``` in ```src/network_kernels.cu``` to get some sort of average values of each layer in YOLO CNN forward network. The performance overhead for computing layer average is acceptable, I suppose it is the preferred way to store information of feature maps.

// %% [markdown]
// ```c
//         cuda_pull_array(l.output_gpu, l.output, l.outputs);
//         cudaStreamSynchronize(get_cuda_stream());
//         float avg_val = 0;
//         int k;
//         for (k = 0; k < l.outputs; ++k) avg_val += l.output[k];
//         printf(" i: %d - avg_val = %f \n", i, avg_val / l.outputs);
// ```

// %%
!./darknet detector test data/kitti.data cfg/yolov3-kitti.cfg yolov3-kitti_last.weights -ext_output -dont_show data/street.png
// Out:
//  CUDA-version: 11040 (11040), cuDNN: 8.3.1, GPU count: 1
//  OpenCV version: 4.2.0
//  0 : compute_capability = 860, cudnn_half = 0, GPU: NVIDIA GeForce RTX 3070 Ti
//    layer   filters  size/strd(dil)      input                output
//    0 conv     32       3 x 3/ 1    256 x1216 x   3 ->  256 x1216 x  32 0.538 BF
//    1 conv     64       3 x 3/ 2    256 x1216 x  32 ->  128 x 608 x  64 2.869 BF
//    2 conv     32       1 x 1/ 1    128 x 608 x  64 ->  128 x 608 x  32 0.319 BF
//    3 conv     64       3 x 3/ 1    128 x 608 x  32 ->  128 x 608 x  64 2.869 BF
//    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 128 x 608 x  64 0.005 BF
//    5 conv    128       3 x 3/ 2    128 x 608 x  64 ->   64 x 304 x 128 2.869 BF
//    6 conv     64       1 x 1/ 1     64 x 304 x 128 ->   64 x 304 x  64 0.319 BF
//    7 conv    128       3 x 3/ 1     64 x 304 x  64 ->   64 x 304 x 128 2.869 BF
//    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs:  64 x 304 x 128 0.002 BF
//    9 conv     64       1 x 1/ 1     64 x 304 x 128 ->   64 x 304 x  64 0.319 BF
//   10 conv    128       3 x 3/ 1     64 x 304 x  64 ->   64 x 304 x 128 2.869 BF
//   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs:  64 x 304 x 128 0.002 BF
//   12 conv    256       3 x 3/ 2     64 x 304 x 128 ->   32 x 152 x 256 2.869 BF
//   13 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   14 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   16 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   17 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   19 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   20 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   22 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   23 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   25 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   26 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   28 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   29 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   31 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   32 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   34 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//   35 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  32 x 152 x 256 0.001 BF
//   37 conv    512       3 x 3/ 2     32 x 152 x 256 ->   16 x  76 x 512 2.869 BF
//   38 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   39 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   41 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   42 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   44 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   45 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   47 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   48 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   50 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   51 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   53 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   54 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   56 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   57 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   59 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   60 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  16 x  76 x 512 0.001 BF
//   62 conv   1024       3 x 3/ 2     16 x  76 x 512 ->    8 x  38 x1024 2.869 BF
//   63 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   64 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   66 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   67 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   69 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   70 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   72 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   73 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:   8 x  38 x1024 0.000 BF
//   75 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   76 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   77 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   78 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   79 conv    512       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x 512 0.319 BF
//   80 conv   1024       3 x 3/ 1      8 x  38 x 512 ->    8 x  38 x1024 2.869 BF
//   81 conv     33       1 x 1/ 1      8 x  38 x1024 ->    8 x  38 x  33 0.021 BF
//   82 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
//   83 route  79 		                           ->    8 x  38 x 512
//   84 conv    256       1 x 1/ 1      8 x  38 x 512 ->    8 x  38 x 256 0.080 BF
//   85 upsample                 2x     8 x  38 x 256 ->   16 x  76 x 256
//   86 route  85 61 	                           ->   16 x  76 x 768
//   87 conv    256       1 x 1/ 1     16 x  76 x 768 ->   16 x  76 x 256 0.478 BF
//   88 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   89 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   90 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   91 conv    256       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x 256 0.319 BF
//   92 conv    512       3 x 3/ 1     16 x  76 x 256 ->   16 x  76 x 512 2.869 BF
//   93 conv     33       1 x 1/ 1     16 x  76 x 512 ->   16 x  76 x  33 0.041 BF
//   94 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
//   95 route  91 		                           ->   16 x  76 x 256
//   96 conv    128       1 x 1/ 1     16 x  76 x 256 ->   16 x  76 x 128 0.080 BF
//   97 upsample                 2x    16 x  76 x 128 ->   32 x 152 x 128
//   98 route  97 36 	                           ->   32 x 152 x 384
//   99 conv    128       1 x 1/ 1     32 x 152 x 384 ->   32 x 152 x 128 0.478 BF
//  100 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//  101 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//  102 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//  103 conv    128       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x 128 0.319 BF
//  104 conv    256       3 x 3/ 1     32 x 152 x 128 ->   32 x 152 x 256 2.869 BF
//  105 conv     33       1 x 1/ 1     32 x 152 x 256 ->   32 x 152 x  33 0.082 BF
//  106 yolo
// [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
// Total BFLOPS 117.536
// avg_outputs = 931279
//  Allocate additional workspace_size = 59.84 MB
// Loading weights from yolov3-kitti_last.weights...net.optimized_memory = 0
// mini_batch = 1, batch = 64, time_steps = 1, train = 0
// Create CUDA-stream - 0
//  Create cudnn-handle 0
// Done! Loaded 107 layers from weights-file
// Failed to write image data/street/res_data/street.jpg
//
//  seen 64, trained: 448 K-images (7 Kilo-batches_64)
// Start processing data/street
// processed path data/street/res_data/street
//  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
//  i: 0 - avg_val = 0.544456
//  i: 1 - avg_val = 0.317995
//  i: 2 - avg_val = 0.248878
//  i: 3 - avg_val = 0.158773
//  i: 4 - avg_val = 0.476681
//  i: 5 - avg_val = 0.428665
//  i: 6 - avg_val = 0.198502
//  i: 7 - avg_val = 0.125726
//  i: 8 - avg_val = 0.554443
//  i: 9 - avg_val = 0.169312
//  i: 10 - avg_val = 0.105918
//  i: 11 - avg_val = 0.660315
//  i: 12 - avg_val = 0.381581
//  i: 13 - avg_val = 0.155402
//  i: 14 - avg_val = 0.004870
//  i: 15 - avg_val = 0.386414
//  i: 16 - avg_val = 0.159771
//  i: 17 - avg_val = 0.015323
//  i: 18 - avg_val = 0.401752
//  i: 19 - avg_val = 0.117750
//  i: 20 - avg_val = 0.008157
//  i: 21 - avg_val = 0.409905
//  i: 22 - avg_val = 0.155365
//  i: 23 - avg_val = 0.005232
//  i: 24 - avg_val = 0.415138
//  i: 25 - avg_val = 0.088309
//  i: 26 - avg_val = -0.005499
//  i: 27 - avg_val = 0.409640
//  i: 28 - avg_val = 0.107795
//  i: 29 - avg_val = -0.006418
//  i: 30 - avg_val = 0.403218
//  i: 31 - avg_val = 0.040988
//  i: 32 - avg_val = 0.023208
//  i: 33 - avg_val = 0.426427
//  i: 34 - avg_val = 0.167919
//  i: 35 - avg_val = 0.039185
//  i: 36 - avg_val = 0.465608
//  i: 37 - avg_val = 0.107114
//  i: 38 - avg_val = 0.348317
//  i: 39 - avg_val = -0.024211
//  i: 40 - avg_val = 0.082903
//  i: 41 - avg_val = 0.182210
//  i: 42 - avg_val = -0.007985
//  i: 43 - avg_val = 0.074918
//  i: 44 - avg_val = 0.009026
//  i: 45 - avg_val = -0.005532
//  i: 46 - avg_val = 0.069386
//  i: 47 - avg_val = 0.035786
//  i: 48 - avg_val = -0.017397
//  i: 49 - avg_val = 0.051988
//  i: 50 - avg_val = 0.020130
//  i: 51 - avg_val = -0.021279
//  i: 52 - avg_val = 0.030709
//  i: 53 - avg_val = -0.028570
//  i: 54 - avg_val = -0.006648
//  i: 55 - avg_val = 0.024061
//  i: 56 - avg_val = 0.141569
//  i: 57 - avg_val = -0.000756
//  i: 58 - avg_val = 0.023305
//  i: 59 - avg_val = 0.009152
//  i: 60 - avg_val = 0.027831
//  i: 61 - avg_val = 0.051136
//  i: 62 - avg_val = -0.011327
//  i: 63 - avg_val = 0.122318
//  i: 64 - avg_val = 0.014056
//  i: 65 - avg_val = 0.002729
//  i: 66 - avg_val = -0.030778
//  i: 67 - avg_val = -0.002702
//  i: 68 - avg_val = 0.000027
//  i: 69 - avg_val = -0.014567
//  i: 70 - avg_val = -0.014819
//  i: 71 - avg_val = -0.014792
//  i: 72 - avg_val = -0.063443
//  i: 73 - avg_val = 0.012937
//  i: 74 - avg_val = -0.001855
//  i: 75 - avg_val = 0.387530
//  i: 76 - avg_val = 0.409404
//  i: 77 - avg_val = 0.407710
//  i: 78 - avg_val = 0.406676
//  i: 79 - avg_val = 0.415069
//  i: 80 - avg_val = 0.411180
//  i: 81 - avg_val = -2.432140
//  i: 82 - avg_val = 0.290216
//  i: 83 - avg_val = 0.415069
//  i: 84 - avg_val = 0.463817
//  i: 85 - avg_val = 0.463815
//  i: 86 - avg_val = 0.188695
//  i: 87 - avg_val = 0.378179
//  i: 88 - avg_val = 0.398601
//  i: 89 - avg_val = 0.372595
//  i: 90 - avg_val = 0.379292
//  i: 91 - avg_val = 0.373405
//  i: 92 - avg_val = 0.377895
//  i: 93 - avg_val = -2.666269
//  i: 94 - avg_val = 0.247977
//  i: 95 - avg_val = 0.373405
//  i: 96 - avg_val = 0.400943
//  i: 97 - avg_val = 0.400944
//  i: 98 - avg_val = 0.444054
//  i: 99 - avg_val = 0.369442
//  i: 100 - avg_val = 0.347938
//  i: 101 - avg_val = 0.338333
//  i: 102 - avg_val = 0.335484
//  i: 103 - avg_val = 0.329910
//  i: 104 - avg_val = 0.423635
//  i: 105 - avg_val = -2.025067
//  i: 106 - avg_val = 0.270260
// data/street.png: Predicted in 199.739000 milli-seconds.
// Car: 93%	(left_x:  217   top_y:  152   width:  282   height:  199)
// Car: 95%	(left_x:  382   top_y:  191   width:  132   height:   96)
// Car: 97%	(left_x:  512   top_y:  190   width:   50   height:   38)
// Car: 70%	(left_x:  658   top_y:  193   width:   43   height:   35)
// Car: 93%	(left_x:  682   top_y:  197   width:   55   height:   46)
// Car: 85%	(left_x:  730   top_y:  198   width:  100   height:   79)
// Car: 99%	(left_x:  750   top_y:  206   width:  169   height:  107)
// Car: 100%	(left_x:  886   top_y:  223   width:  361   height:  154)

// %% [markdown]
// #### 2. Extract the feature map itself ?
//
// Uncomment the following lines within the function ```forward_network_gpu``` in ```src/network_kernels.cu``` to save the feature maps of each layer.
//
// **Caution:** Enable saving feature map will lead to significant performance and storage overheads. Besides, in the case of processing a series of test images, the source code should be overhauled to save feature maps to certain directories.

// %% [markdown]
// ```c
//         cuda_pull_array(l.output_gpu, l.output, l.batch*l.outputs);
//         if (l.out_w >= 0 && l.out_h >= 1 && l.c >= 3) {
//             int j;
//             for (j = 0; j < l.out_c; ++j) {
//                 image img = make_image(l.out_w, l.out_h, 3);
//                 memcpy(img.data, l.output + l.out_w*l.out_h*j, l.out_w*l.out_h * 1 * sizeof(float));
//                 memcpy(img.data + l.out_w*l.out_h * 1, l.output + l.out_w*l.out_h*j, l.out_w*l.out_h * 1 * sizeof(float));
//                 memcpy(img.data + l.out_w*l.out_h * 2, l.output + l.out_w*l.out_h*j, l.out_w*l.out_h * 1 * sizeof(float));
//                 char buff[256];
//                 sprintf(buff, "layer-%d slice-%d", i, j);
//                 // show_image(img, buff);
//                 save_image(img, buff);
//             }
//             // cvWaitKey(0); // wait press-key in console
//             // cvDestroyAllWindows();
//         }
// ```

// %% [markdown]
// ## C. Run Darknet detection for a series of images

// %% [markdown]
// Now the Darknet repo is set to properly print/save the information required for fault injection campaign for **single** image. To process a **list of images** and save the **classifications with the coordinates of bounding boxes**, using the following command:

// %%
!./darknet detector test data/kitti.data cfg/yolov3-kitti.cfg yolov3-kitti_last.weights -dont_show -ext_output < data/test.txt > kitti_results.txt

// %%
!cat kitti_results.txt
// Out:
// net.optimized_memory = 0
// mini_batch = 1, batch = 64, time_steps = 1, train = 0
// Create CUDA-stream - 0
//  Create cudnn-handle 0
//
//  seen 64, trained: 448 K-images (7 Kilo-batches_64)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005142.png: Predicted in 15.233000 milli-seconds.
// Pedestrian: 75%	(left_x:  468   top_y:  164   width:   62   height:  135)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006877.png: Predicted in 15.061000 milli-seconds.
// Car: 81%	(left_x:    2   top_y:  203   width:   65   height:   35)
// Car: 58%	(left_x:  127   top_y:  197   width:   66   height:   29)
// Car: 80%	(left_x:  333   top_y:  188   width:   41   height:   21)
// Car: 55%	(left_x:  381   top_y:  183   width:   32   height:   22)
// Car: 95%	(left_x:  425   top_y:  181   width:   38   height:   21)
// Car: 99%	(left_x:  503   top_y:  176   width:  268   height:  175)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005440.png: Predicted in 13.529000 milli-seconds.
// Car: 46%	(left_x:  409   top_y:  187   width:   29   height:   19)
// Truck: 95%	(left_x:  565   top_y:  141   width:   58   height:   72)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006411.png: Predicted in 15.083000 milli-seconds.
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006307.png: Predicted in 15.714000 milli-seconds.
// Truck: 80%	(left_x:   14   top_y:   73   width:  402   height:  199)
// Tram: 34%	(left_x:   14   top_y:   73   width:  402   height:  199)
// Car: 98%	(left_x:  420   top_y:  179   width:  104   height:   70)
// Car: 34%	(left_x:  496   top_y:  180   width:   46   height:   31)
// Tram: 36%	(left_x:  573   top_y:  154   width:   78   height:   42)
// Car: 97%	(left_x:  607   top_y:  172   width:   71   height:   63)
// Car: 64%	(left_x:  719   top_y:  173   width:   28   height:   20)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006015.png: Predicted in 16.785000 milli-seconds.
// Car: 99%	(left_x:  308   top_y:  187   width:  149   height:  103)
// Car: 83%	(left_x:  470   top_y:  174   width:   34   height:   27)
// Car: 27%	(left_x:  482   top_y:  174   width:   44   height:   30)
// Car: 97%	(left_x:  533   top_y:  174   width:   57   height:   50)
// Car: 56%	(left_x:  546   top_y:  173   width:   45   height:   31)
// Car: 79%	(left_x:  589   top_y:  172   width:   36   height:   27)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005773.png: Predicted in 15.321000 milli-seconds.
// Car: 90%	(left_x:  239   top_y:  183   width:   63   height:   26)
// Pedestrian: 39%	(left_x:  447   top_y:  174   width:   17   height:   50)
// Car: 96%	(left_x:  452   top_y:  178   width:   82   height:   33)
// Car: 27%	(left_x:  502   top_y:  175   width:   37   height:   21)
// Car: 52%	(left_x:  553   top_y:  174   width:   29   height:   18)
// Car: 51%	(left_x:  580   top_y:  174   width:   30   height:   19)
// Car: 97%	(left_x:  689   top_y:  170   width:   89   height:   26)
// Car: 100%	(left_x:  798   top_y:  176   width:  412   height:  194)
// Cyclist: 52%	(left_x:  910   top_y:  173   width:  106   height:   65)
// Car: 92%	(left_x:  910   top_y:  168   width:  108   height:   26)
// Van: 64%	(left_x: 1168   top_y:  159   width:   62   height:   32)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007186.png: Predicted in 15.183000 milli-seconds.
// Car: 88%	(left_x:  347   top_y:  183   width:  113   height:   41)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006883.png: Predicted in 15.236000 milli-seconds.
// Car: 94%	(left_x:  184   top_y:  160   width:   61   height:   31)
// Car: 68%	(left_x:  279   top_y:  173   width:   44   height:   23)
// Car: 99%	(left_x:  574   top_y:  172   width:   46   height:   44)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005405.png: Predicted in 13.761000 milli-seconds.
// Car: 100%	(left_x:  273   top_y:  179   width:  108   height:   61)
// Van: 94%	(left_x:  316   top_y:  172   width:   57   height:   47)
// Van: 68%	(left_x:  474   top_y:  172   width:   29   height:   29)
// Car: 98%	(left_x:  585   top_y:  176   width:   29   height:   26)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005337.png: Predicted in 14.900000 milli-seconds.
// Van: 84%	(left_x:   13   top_y:  174   width:  236   height:  121)
// Car: 27%	(left_x:  252   top_y:  192   width:   77   height:   46)
// Car: 74%	(left_x:  316   top_y:  189   width:   92   height:   50)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006492.png: Predicted in 15.126000 milli-seconds.
// Car: 63%	(left_x:  237   top_y:  179   width:   54   height:   29)
// Van: 97%	(left_x:  362   top_y:  119   width:  123   height:  131)
// Car: 98%	(left_x:  548   top_y:  181   width:   62   height:   50)
// Cyclist: 70%	(left_x:  851   top_y:  186   width:   21   height:   34)
// Car: 95%	(left_x:  931   top_y:  190   width:   66   height:   29)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006669.png: Predicted in 15.058000 milli-seconds.
// Van: 88%	(left_x:  782   top_y:   91   width:  280   height:  258)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006744.png: Predicted in 13.783000 milli-seconds.
// Car: 55%	(left_x:  552   top_y:  164   width:   25   height:   19)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006698.png: Predicted in 15.057000 milli-seconds.
// Tram: 83%	(left_x:  348   top_y:  159   width:   91   height:   45)
// Car: 99%	(left_x:  581   top_y:  180   width:   28   height:   27)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006410.png: Predicted in 15.167000 milli-seconds.
// Car: 99%	(left_x:   -0   top_y:  182   width:  367   height:  183)
// Car: 98%	(left_x:  295   top_y:  192   width:  138   height:   93)
// Car: 84%	(left_x:  386   top_y:  191   width:  107   height:   65)
// Car: 88%	(left_x:  453   top_y:  185   width:   67   height:   50)
// Car: 48%	(left_x:  571   top_y:  180   width:   35   height:   21)
// Car: 95%	(left_x:  709   top_y:  174   width:   63   height:   50)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006552.png: Predicted in 15.117000 milli-seconds.
// Pedestrian: 56%	(left_x:  232   top_y:  159   width:   76   height:  173)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006047.png: Predicted in 15.077000 milli-seconds.
// Car: 95%	(left_x:  281   top_y:  194   width:  122   height:   73)
// Car: 85%	(left_x:  478   top_y:  185   width:   39   height:   27)
// Car: 56%	(left_x:  497   top_y:  183   width:   34   height:   27)
// Car: 80%	(left_x:  632   top_y:  173   width:   39   height:   28)
// Car: 93%	(left_x:  714   top_y:  174   width:  155   height:  101)
// Car: 100%	(left_x:  811   top_y:  177   width:  401   height:  187)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006636.png: Predicted in 13.788000 milli-seconds.
// Tram: 84%	(left_x:  227   top_y:  145   width:  177   height:   68)
// Car: 99%	(left_x:  582   top_y:  177   width:   29   height:   28)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005376.png: Predicted in 14.929000 milli-seconds.
// Car: 59%	(left_x:   -3   top_y:  202   width:  169   height:   84)
// Car: 98%	(left_x:  235   top_y:  194   width:  228   height:  100)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005395.png: Predicted in 15.101000 milli-seconds.
// Car: 97%	(left_x:    0   top_y:  209   width:  203   height:  168)
// Car: 99%	(left_x:  211   top_y:  198   width:  186   height:  110)
// Car: 97%	(left_x:  450   top_y:  183   width:   55   height:   42)
// Van: 93%	(left_x:  498   top_y:  157   width:   40   height:   49)
// Car: 73%	(left_x:  545   top_y:  178   width:   35   height:   31)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005695.png: Predicted in 15.042000 milli-seconds.
// Car: 88%	(left_x:   -2   top_y:  182   width:  235   height:  143)
// Car: 91%	(left_x:  131   top_y:  169   width:  242   height:  100)
// Car: 93%	(left_x:  335   top_y:  170   width:  127   height:   59)
// Van: 65%	(left_x:  351   top_y:  165   width:  127   height:   61)
// Van: 58%	(left_x:  402   top_y:  171   width:   94   height:   39)
// Car: 35%	(left_x:  402   top_y:  171   width:   94   height:   39)
// Car: 89%	(left_x:  442   top_y:  176   width:   77   height:   31)
// Car: 98%	(left_x:  655   top_y:  173   width:   39   height:   34)
// Car: 97%	(left_x:  679   top_y:  177   width:   63   height:   50)
// Car: 100%	(left_x:  745   top_y:  182   width:  189   height:  125)
// Car: 100%	(left_x:  821   top_y:  197   width:  457   height:  186)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005409.png: Predicted in 15.164000 milli-seconds.
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007225.png: Predicted in 15.142000 milli-seconds.
// Car: 100%	(left_x:   82   top_y:  188   width:  357   height:  188)
// Car: 94%	(left_x:  543   top_y:  178   width:   31   height:   23)
// Van: 95%	(left_x:  662   top_y:  162   width:   44   height:   49)
// Car: 79%	(left_x:  663   top_y:  180   width:   50   height:   39)
// Car: 84%	(left_x:  676   top_y:  182   width:   58   height:   48)
// Car: 100%	(left_x:  860   top_y:  219   width:  401   height:  158)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006910.png: Predicted in 15.079000 milli-seconds.
// Car: 95%	(left_x:    9   top_y:  209   width:   83   height:   43)
// Van: 87%	(left_x:  172   top_y:  174   width:  137   height:   79)
// Car: 30%	(left_x:  309   top_y:  186   width:   73   height:   31)
// Truck: 87%	(left_x:  704   top_y:  101   width:  203   height:  101)
// Car: 91%	(left_x:  859   top_y:  166   width:   89   height:   47)
// Car: 64%	(left_x:  954   top_y:  156   width:  152   height:   58)
// Pedestrian: 34%	(left_x: 1093   top_y:  130   width:   63   height:  179)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006224.png: Predicted in 13.791000 milli-seconds.
// Car: 99%	(left_x:  159   top_y:  191   width:  184   height:  104)
// Car: 95%	(left_x:  249   top_y:  181   width:  161   height:   84)
// Car: 87%	(left_x:  387   top_y:  181   width:   91   height:   46)
// Car: 76%	(left_x:  469   top_y:  174   width:   62   height:   35)
// Car: 85%	(left_x:  506   top_y:  185   width:   64   height:   47)
// Car: 98%	(left_x:  586   top_y:  179   width:   51   height:   41)
// Car: 38%	(left_x:  593   top_y:  175   width:   39   height:   29)
// Truck: 38%	(left_x:  670   top_y:  105   width:  137   height:  124)
// Car: 100%	(left_x:  716   top_y:  186   width:  131   height:   88)
// Pedestrian: 33%	(left_x:  789   top_y:  161   width:   34   height:   80)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007070.png: Predicted in 13.596000 milli-seconds.
// Car: 59%	(left_x:  398   top_y:  182   width:   39   height:   29)
// Pedestrian: 52%	(left_x:  546   top_y:  173   width:   15   height:   37)
// Car: 79%	(left_x:  582   top_y:  178   width:   50   height:   36)
// Car: 99%	(left_x:  591   top_y:  180   width:   71   height:   53)
// Van: 28%	(left_x:  658   top_y:  168   width:   35   height:   37)
// Cyclist: 81%	(left_x:  716   top_y:  167   width:   38   height:   38)
// Cyclist: 38%	(left_x:  731   top_y:  168   width:   40   height:   41)
// Pedestrian: 53%	(left_x:  855   top_y:  160   width:   39   height:   62)
// Pedestrian: 50%	(left_x:  872   top_y:  160   width:   29   height:   66)
// Car: 82%	(left_x: 1000   top_y:  164   width:  102   height:   46)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006717.png: Predicted in 15.112000 milli-seconds.
// Car: 100%	(left_x:  240   top_y:  198   width:  132   height:   74)
// Car: 97%	(left_x:  463   top_y:  188   width:   59   height:   47)
// Car: 99%	(left_x:  576   top_y:  183   width:   51   height:   46)
// Van: 43%	(left_x:  778   top_y:  167   width:   33   height:   30)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006002.png: Predicted in 15.169000 milli-seconds.
// Car: 100%	(left_x:  432   top_y:  190   width:   95   height:   51)
// Car: 91%	(left_x:  496   top_y:  185   width:   51   height:   36)
// Car: 88%	(left_x:  528   top_y:  178   width:   33   height:   32)
// Car: 38%	(left_x:  544   top_y:  173   width:   29   height:   23)
// Car: 95%	(left_x:  606   top_y:  175   width:   47   height:   41)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007013.png: Predicted in 15.037000 milli-seconds.
// Truck: 29%	(left_x:   -6   top_y:   55   width:  263   height:  252)
// Car: 98%	(left_x:  401   top_y:  186   width:   59   height:   28)
// Car: 59%	(left_x:  507   top_y:  180   width:   32   height:   21)
// Car: 75%	(left_x:  598   top_y:  175   width:   51   height:   36)
// Car: 99%	(left_x:  692   top_y:  171   width:   43   height:   31)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005821.png: Predicted in 14.262000 milli-seconds.
// Car: 100%	(left_x:   36   top_y:  201   width:  323   height:  176)
// Van: 73%	(left_x:  311   top_y:  172   width:  167   height:  115)
// Car: 87%	(left_x:  498   top_y:  186   width:   53   height:   34)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005582.png: Predicted in 14.909000 milli-seconds.
// Car: 89%	(left_x:  413   top_y:  179   width:   34   height:   20)
// Truck: 98%	(left_x:  603   top_y:  156   width:   26   height:   31)
// Cyclist: 87%	(left_x:  669   top_y:  163   width:   11   height:   28)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006695.png: Predicted in 15.156000 milli-seconds.
// Car: 86%	(left_x:   -5   top_y:  194   width:  110   height:   69)
// Car: 32%	(left_x:  436   top_y:  178   width:   44   height:   46)
// Car: 85%	(left_x:  624   top_y:  177   width:   63   height:   36)
// Car: 44%	(left_x:  642   top_y:  180   width:   69   height:   37)
// Car: 52%	(left_x:  698   top_y:  177   width:  137   height:   75)
// Car: 42%	(left_x:  719   top_y:  165   width:  168   height:  109)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005223.png: Predicted in 15.135000 milli-seconds.
// Car: 98%	(left_x:  311   top_y:  185   width:  172   height:  137)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007433.png: Predicted in 15.116000 milli-seconds.
// Car: 100%	(left_x:   15   top_y:  188   width:  446   height:  185)
// Car: 92%	(left_x:  363   top_y:  166   width:   63   height:   29)
// Car: 96%	(left_x:  468   top_y:  168   width:   75   height:   35)
// Car: 78%	(left_x:  565   top_y:  167   width:   48   height:   28)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007409.png: Predicted in 13.782000 milli-seconds.
// Car: 97%	(left_x:  676   top_y:  186   width:   81   height:   55)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006806.png: Predicted in 14.791000 milli-seconds.
// Car: 91%	(left_x:  344   top_y:  188   width:  125   height:   96)
// Van: 44%	(left_x:  428   top_y:  163   width:   83   height:   85)
// Car: 58%	(left_x:  519   top_y:  177   width:   36   height:   29)
// Car: 49%	(left_x:  866   top_y:  186   width:  375   height:  188)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007400.png: Predicted in 15.252000 milli-seconds.
// Car: 99%	(left_x:   -9   top_y:  190   width:  254   height:   98)
// Car: 92%	(left_x:  105   top_y:  185   width:  204   height:   77)
// Car: 54%	(left_x:  229   top_y:  183   width:  128   height:   64)
// Car: 85%	(left_x:  279   top_y:  180   width:  121   height:   60)
// Car: 71%	(left_x:  366   top_y:  185   width:   77   height:   38)
// Car: 78%	(left_x:  393   top_y:  183   width:   66   height:   34)
// Car: 82%	(left_x:  423   top_y:  180   width:   57   height:   30)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006563.png: Predicted in 15.208000 milli-seconds.
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007274.png: Predicted in 15.160000 milli-seconds.
// Car: 76%	(left_x:  575   top_y:  176   width:   52   height:   32)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006673.png: Predicted in 14.777000 milli-seconds.
// Car: 94%	(left_x:  282   top_y:  167   width:  147   height:   82)
// Van: 70%	(left_x:  287   top_y:  162   width:  150   height:   86)
// Van: 33%	(left_x:  350   top_y:  161   width:  156   height:   70)
// Car: 100%	(left_x:  504   top_y:  167   width:  261   height:  193)
// Car: 99%	(left_x:  937   top_y:  172   width:  157   height:   47)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007009.png: Predicted in 13.664000 milli-seconds.
// Car: 58%	(left_x:  588   top_y:  172   width:   40   height:   37)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006413.png: Predicted in 15.146000 milli-seconds.
// Car: 98%	(left_x:  153   top_y:  198   width:  169   height:  101)
// Car: 99%	(left_x:  450   top_y:  188   width:   73   height:   52)
// Car: 100%	(left_x:  573   top_y:  182   width:   52   height:   46)
// Van: 85%	(left_x:  786   top_y:  168   width:   29   height:   26)
// Truck: 41%	(left_x:  805   top_y:  160   width:   50   height:   35)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007474.png: Predicted in 15.155000 milli-seconds.
// Car: 99%	(left_x:  582   top_y:  190   width:  114   height:   80)
// Car: 71%	(left_x:  654   top_y:  193   width:   73   height:   50)
// Car: 73%	(left_x:  710   top_y:  190   width:   51   height:   38)
// Car: 54%	(left_x:  738   top_y:  187   width:   43   height:   38)
// Car: 99%	(left_x:  771   top_y:  185   width:   68   height:   59)
// Car: 39%	(left_x:  774   top_y:  184   width:   42   height:   38)
// Van: 35%	(left_x:  806   top_y:  167   width:   29   height:   29)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006353.png: Predicted in 15.006000 milli-seconds.
// Car: 95%	(left_x:  652   top_y:  164   width:   31   height:   26)
// Car: 99%	(left_x:  804   top_y:  170   width:  127   height:   48)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007164.png: Predicted in 14.295000 milli-seconds.
// Van: 97%	(left_x:  174   top_y:  153   width:  160   height:  104)
// Car: 97%	(left_x:  454   top_y:  184   width:   36   height:   24)
// Car: 91%	(left_x:  594   top_y:  180   width:   27   height:   25)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006577.png: Predicted in 14.895000 milli-seconds.
// Car: 68%	(left_x:  536   top_y:  182   width:   29   height:   23)
// Car: 98%	(left_x:  580   top_y:  180   width:   32   height:   33)
// Van: 90%	(left_x:  593   top_y:  167   width:   17   height:   28)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006490.png: Predicted in 15.070000 milli-seconds.
// Car: 83%	(left_x:   82   top_y:  187   width:   68   height:   35)
// Car: 35%	(left_x:  114   top_y:  184   width:   61   height:   34)
// Car: 88%	(left_x:  154   top_y:  185   width:   57   height:   31)
// Car: 34%	(left_x:  234   top_y:  181   width:   54   height:   28)
// Car: 55%	(left_x:  268   top_y:  181   width:   40   height:   25)
// Truck: 95%	(left_x:  589   top_y:  130   width:   74   height:   72)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006595.png: Predicted in 15.105000 milli-seconds.
// Car: 77%	(left_x:    5   top_y:  217   width:  125   height:  154)
// Car: 98%	(left_x:  125   top_y:  200   width:  202   height:  106)
// Car: 96%	(left_x:  341   top_y:  180   width:  100   height:   67)
// Car: 78%	(left_x:  407   top_y:  181   width:   67   height:   44)
// Car: 59%	(left_x:  459   top_y:  181   width:   48   height:   30)
// Car: 80%	(left_x:  535   top_y:  177   width:   38   height:   23)
// Car: 89%	(left_x:  637   top_y:  174   width:   30   height:   20)
// Car: 45%	(left_x:  694   top_y:  167   width:   67   height:   23)
// Car: 98%	(left_x:  751   top_y:  177   width:  229   height:  142)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006157.png: Predicted in 15.009000 milli-seconds.
// Car: 97%	(left_x:   -7   top_y:  195   width:  299   height:  172)
// Car: 93%	(left_x:  223   top_y:  193   width:  202   height:  112)
// Car: 96%	(left_x:  389   top_y:  189   width:  107   height:   64)
// Car: 79%	(left_x:  484   top_y:  182   width:   62   height:   37)
// Van: 90%	(left_x:  509   top_y:  170   width:   51   height:   47)
// Truck: 82%	(left_x:  603   top_y:  148   width:   60   height:   50)
// Car: 97%	(left_x:  670   top_y:  179   width:   63   height:   54)
// Car: 85%	(left_x:  724   top_y:  169   width:   66   height:   30)
// Car: 43%	(left_x:  771   top_y:  169   width:   61   height:   33)
// Car: 75%	(left_x:  792   top_y:  172   width:   79   height:   36)
// Car: 84%	(left_x:  831   top_y:  170   width:  103   height:   49)
// Car: 55%	(left_x:  926   top_y:  167   width:  100   height:   48)
// Van: 75%	(left_x:  990   top_y:  130   width:  250   height:  130)
// Car: 68%	(left_x: 1009   top_y:  239   width:  244   height:  128)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007053.png: Predicted in 15.067000 milli-seconds.
// Car: 100%	(left_x:  266   top_y:  196   width:  201   height:  126)
// Car: 92%	(left_x:  586   top_y:  182   width:   57   height:   31)
// Car: 35%	(left_x:  763   top_y:  177   width:   38   height:   24)
// Cyclist: 76%	(left_x:  777   top_y:  161   width:   60   height:  149)
// Van: 26%	(left_x:  848   top_y:  146   width:  120   height:   58)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005841.png: Predicted in 13.775000 milli-seconds.
// Tram: 58%	(left_x:  442   top_y:  156   width:   65   height:   47)
// Car: 96%	(left_x:  550   top_y:  176   width:   21   height:   21)
// Truck: 99%	(left_x:  586   top_y:  164   width:   23   height:   29)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006690.png: Predicted in 14.995000 milli-seconds.
// Car: 49%	(left_x:    7   top_y:  181   width:   74   height:  175)
// Car: 99%	(left_x:  338   top_y:  187   width:   69   height:   40)
// Tram: 99%	(left_x:  632   top_y:  151   width:   71   height:   41)
// Cyclist: 77%	(left_x:  898   top_y:  156   width:   25   height:   55)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007355.png: Predicted in 15.108000 milli-seconds.
// Car: 96%	(left_x:  595   top_y:  177   width:   28   height:   24)
// Car: 93%	(left_x:  662   top_y:  177   width:   55   height:   45)
// Car: 100%	(left_x:  726   top_y:  174   width:  154   height:  118)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005708.png: Predicted in 15.082000 milli-seconds.
// Car: 99%	(left_x:   18   top_y:  215   width:  289   height:  165)
// Car: 97%	(left_x:  629   top_y:  178   width:   37   height:   26)
// Car: 98%	(left_x:  955   top_y:  206   width:  281   height:  172)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005516.png: Predicted in 15.009000 milli-seconds.
// Car: 100%	(left_x:   31   top_y:  195   width:  187   height:   81)
// Car: 93%	(left_x:  233   top_y:  184   width:   66   height:   33)
// Car: 48%	(left_x:  335   top_y:  183   width:   66   height:   35)
// Car: 100%	(left_x:  365   top_y:  189   width:   81   height:   50)
// Car: 84%	(left_x:  413   top_y:  180   width:   53   height:   31)
// Car: 56%	(left_x:  447   top_y:  181   width:   44   height:   25)
// Car: 81%	(left_x:  519   top_y:  179   width:   41   height:   23)
// Car: 32%	(left_x:  584   top_y:  178   width:   29   height:   15)
// Car: 100%	(left_x:  597   top_y:  180   width:  135   height:  121)
// Car: 95%	(left_x:  681   top_y:  176   width:   68   height:   35)
// Car: 93%	(left_x:  725   top_y:  171   width:  116   height:   60)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005258.png: Predicted in 15.043000 milli-seconds.
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006784.png: Predicted in 13.797000 milli-seconds.
// Car: 26%	(left_x:  514   top_y:  189   width:   19   height:   15)
// Car: 96%	(left_x:  543   top_y:  190   width:   29   height:   26)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007468.png: Predicted in 14.958000 milli-seconds.
// Car: 90%	(left_x:   11   top_y:  180   width:  265   height:  110)
// Car: 47%	(left_x:  578   top_y:  169   width:   37   height:   45)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007382.png: Predicted in 15.026000 milli-seconds.
// Car: 100%	(left_x:  264   top_y:  175   width:  140   height:   60)
// Car: 88%	(left_x:  316   top_y:  172   width:   72   height:   32)
// Car: 95%	(left_x:  545   top_y:  168   width:   46   height:   33)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005465.png: Predicted in 14.986000 milli-seconds.
// Car: 98%	(left_x:    3   top_y:  189   width:  190   height:  179)
// Car: 89%	(left_x:  104   top_y:  185   width:  220   height:  129)
// Car: 98%	(left_x:  271   top_y:  184   width:  173   height:   61)
// Car: 60%	(left_x:  399   top_y:  179   width:  109   height:   35)
// Car: 34%	(left_x:  554   top_y:  181   width:   30   height:   19)
// Car: 56%	(left_x:  642   top_y:  179   width:   42   height:   34)
// Car: 99%	(left_x:  654   top_y:  185   width:   54   height:   43)
// Car: 100%	(left_x:  861   top_y:  187   width:  354   height:  110)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006241.png: Predicted in 14.368000 milli-seconds.
// Car: 99%	(left_x:  471   top_y:  178   width:   60   height:   44)
// Car: 72%	(left_x:  535   top_y:  177   width:   31   height:   27)
// Car: 100%	(left_x:  594   top_y:  176   width:   44   height:   39)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005252.png: Predicted in 13.670000 milli-seconds.
// Car: 98%	(left_x:  524   top_y:  174   width:   30   height:   29)
// Car: 52%	(left_x:  543   top_y:  176   width:   20   height:   17)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007363.png: Predicted in 15.279000 milli-seconds.
// Car: 86%	(left_x:  187   top_y:  174   width:   79   height:   28)
// Car: 63%	(left_x:  233   top_y:  173   width:   58   height:   27)
// Car: 96%	(left_x:  307   top_y:  174   width:   36   height:   21)
// Car: 100%	(left_x:  585   top_y:  175   width:   54   height:   49)
// Cyclist: 45%	(left_x:  748   top_y:  177   width:   10   height:   24)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005899.png: Predicted in 15.102000 milli-seconds.
// Pedestrian: 48%	(left_x:  551   top_y:  157   width:   75   height:  187)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007087.png: Predicted in 15.262000 milli-seconds.
// Car: 98%	(left_x:  484   top_y:  183   width:   56   height:   36)
// Car: 72%	(left_x:  670   top_y:  175   width:   31   height:   24)
// Car: 93%	(left_x:  693   top_y:  183   width:   63   height:   46)
// Car: 97%	(left_x:  726   top_y:  181   width:   92   height:   79)
// Car: 85%	(left_x:  920   top_y:  176   width:  156   height:   48)
// Car: 90%	(left_x: 1042   top_y:  173   width:  193   height:   64)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006533.png: Predicted in 15.074000 milli-seconds.
// Car: 98%	(left_x:  315   top_y:  179   width:   81   height:   55)
// Van: 91%	(left_x:  338   top_y:  171   width:   50   height:   48)
// Van: 59%	(left_x:  480   top_y:  172   width:   27   height:   23)
// Car: 98%	(left_x:  587   top_y:  176   width:   28   height:   26)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005230.png: Predicted in 13.812000 milli-seconds.
// Pedestrian: 34%	(left_x: 1042   top_y:  153   width:   27   height:   76)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006873.png: Predicted in 13.781000 milli-seconds.
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006893.png: Predicted in 15.375000 milli-seconds.
// Car: 96%	(left_x:  711   top_y:  171   width:   20   height:   15)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006809.png: Predicted in 15.293000 milli-seconds.
// Car: 100%	(left_x:  206   top_y:  189   width:  171   height:  121)
// Pedestrian: 30%	(left_x:  441   top_y:  200   width:   14   height:   41)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007459.png: Predicted in 15.105000 milli-seconds.
// Car: 95%	(left_x:  401   top_y:  175   width:  142   height:  120)
// Car: 82%	(left_x:  488   top_y:  169   width:  100   height:   79)
// Car: 93%	(left_x:  551   top_y:  175   width:   68   height:   52)
// Car: 84%	(left_x:  620   top_y:  180   width:   46   height:   31)
// Car: 94%	(left_x:  942   top_y:  243   width:  299   height:  134)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006633.png: Predicted in 15.187000 milli-seconds.
// Car: 94%	(left_x:  147   top_y:  179   width:  162   height:   89)
// Van: 90%	(left_x:  263   top_y:  176   width:   66   height:   48)
// Van: 94%	(left_x:  446   top_y:  166   width:   44   height:   39)
// Car: 98%	(left_x:  587   top_y:  174   width:   30   height:   28)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005611.png: Predicted in 14.780000 milli-seconds.
// Car: 57%	(left_x:  467   top_y:  178   width:   54   height:   25)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005912.png: Predicted in 13.841000 milli-seconds.
// Tram: 83%	(left_x:   42   top_y:  -18   width:  413   height:  395)
// Tram: 56%	(left_x:  357   top_y:   61   width:  158   height:  208)
// Car: 85%	(left_x:  578   top_y:  177   width:   76   height:   76)
// Cyclist: 92%	(left_x:  824   top_y:  155   width:   47   height:   80)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005116.png: Predicted in 14.665000 milli-seconds.
// Car: 95%	(left_x:  355   top_y:  189   width:   55   height:   30)
// Van: 26%	(left_x:  433   top_y:  179   width:   33   height:   30)
// Car: 95%	(left_x:  578   top_y:  185   width:   62   height:   39)
// Car: 95%	(left_x:  597   top_y:  190   width:   82   height:   57)
// Van: 65%	(left_x:  662   top_y:  172   width:   52   height:   42)
// Cyclist: 98%	(left_x:  780   top_y:  172   width:   48   height:   56)
// Pedestrian: 37%	(left_x: 1018   top_y:  167   width:   45   height:   87)
// Car: 99%	(left_x: 1117   top_y:  174   width:  124   height:   61)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007111.png: Predicted in 14.970000 milli-seconds.
// Car: 99%	(left_x:  292   top_y:  197   width:  400   height:  106)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005072.png: Predicted in 15.085000 milli-seconds.
// Car: 97%	(left_x:   12   top_y:  228   width:  229   height:  143)
// Car: 79%	(left_x:  167   top_y:  216   width:  144   height:   85)
// Car: 97%	(left_x:  276   top_y:  201   width:   79   height:   48)
// Car: 86%	(left_x:  346   top_y:  201   width:   33   height:   24)
// Car: 84%	(left_x:  465   top_y:  204   width:   55   height:   34)
// Car: 94%	(left_x:  504   top_y:  196   width:  100   height:   68)
// Car: 99%	(left_x:  558   top_y:  204   width:  159   height:   90)
// Car: 98%	(left_x:  624   top_y:  212   width:  259   height:  133)
// Car: 100%	(left_x:  789   top_y:  211   width:  456   height:  176)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005190.png: Predicted in 13.785000 milli-seconds.
// Car: 71%	(left_x:  107   top_y:  181   width:  215   height:   98)
// Car: 71%	(left_x:  175   top_y:  185   width:  211   height:   79)
// Car: 93%	(left_x:  269   top_y:  184   width:  152   height:   60)
// Car: 91%	(left_x:  336   top_y:  177   width:  134   height:   53)
// Car: 54%	(left_x:  402   top_y:  173   width:   95   height:   46)
// Van: 30%	(left_x:  402   top_y:  173   width:   95   height:   46)
// Car: 41%	(left_x:  458   top_y:  176   width:   66   height:   28)
// Car: 71%	(left_x:  634   top_y:  179   width:   33   height:   29)
// Car: 98%	(left_x:  646   top_y:  180   width:   51   height:   43)
// Car: 99%	(left_x:  673   top_y:  173   width:  108   height:   85)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005627.png: Predicted in 13.551000 milli-seconds.
// Car: 100%	(left_x:   -1   top_y:  191   width:  332   height:  160)
// Car: 60%	(left_x:  224   top_y:  194   width:   78   height:   35)
// Car: 77%	(left_x:  620   top_y:  171   width:   35   height:   29)
// Car: 69%	(left_x:  664   top_y:  173   width:   35   height:   32)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006049.png: Predicted in 14.673000 milli-seconds.
// Van: 65%	(left_x:  705   top_y:  165   width:   29   height:   34)
// Car: 73%	(left_x:  798   top_y:  175   width:   53   height:   26)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006616.png: Predicted in 15.161000 milli-seconds.
// Car: 75%	(left_x:  529   top_y:  177   width:   25   height:   19)
// Car: 100%	(left_x:  559   top_y:  177   width:   56   height:   47)
// Car: 53%	(left_x:  854   top_y:  169   width:   40   height:   21)
// Van: 96%	(left_x:  892   top_y:  158   width:   53   height:   30)
// Van: 65%	(left_x:  965   top_y:  151   width:  123   height:   42)
// Truck: 72%	(left_x: 1135   top_y:  129   width:  101   height:   64)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006444.png: Predicted in 14.968000 milli-seconds.
// Pedestrian: 25%	(left_x:   62   top_y:  172   width:   84   height:  172)
// Van: 34%	(left_x:  470   top_y:  157   width:   61   height:   59)
// Pedestrian: 26%	(left_x:  595   top_y:  163   width:   18   height:   49)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006305.png: Predicted in 15.137000 milli-seconds.
// Car: 74%	(left_x:  554   top_y:  185   width:   24   height:   21)
// Van: 99%	(left_x:  647   top_y:  172   width:   49   height:   47)
// Car: 99%	(left_x:  782   top_y:  180   width:  241   height:  176)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006197.png: Predicted in 15.063000 milli-seconds.
// Car: 96%	(left_x:  -19   top_y:  199   width:  335   height:  100)
// Car: 65%	(left_x:  459   top_y:  184   width:   44   height:   24)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007154.png: Predicted in 15.066000 milli-seconds.
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007123.png: Predicted in 14.264000 milli-seconds.
// Car: 87%	(left_x:   11   top_y:  222   width:  207   height:  153)
// Car: 38%	(left_x:  265   top_y:  186   width:  188   height:   75)
// Car: 89%	(left_x:  337   top_y:  180   width:  161   height:   68)
// Pedestrian: 58%	(left_x:  513   top_y:  171   width:   15   height:   51)
// Car: 28%	(left_x:  847   top_y:  170   width:  215   height:  109)
// Car: 76%	(left_x:  886   top_y:  161   width:  300   height:  141)
// Car: 92%	(left_x:  997   top_y:  182   width:  240   height:  195)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005224.png: Predicted in 13.793000 milli-seconds.
// Car: 100%	(left_x:   73   top_y:  196   width:  236   height:   76)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005857.png: Predicted in 13.533000 milli-seconds.
// Car: 99%	(left_x:  275   top_y:  190   width:   65   height:   37)
// Truck: 96%	(left_x:  631   top_y:  151   width:   66   height:   59)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005058.png: Predicted in 15.274000 milli-seconds.
// Car: 99%	(left_x:    3   top_y:  189   width:  179   height:  130)
// Van: 95%	(left_x:  104   top_y:  163   width:  119   height:   76)
// Car: 91%	(left_x:  251   top_y:  184   width:   95   height:   55)
// Car: 64%	(left_x:  258   top_y:  185   width:   63   height:   32)
// Car: 84%	(left_x:  336   top_y:  183   width:   59   height:   35)
// Car: 98%	(left_x:  397   top_y:  181   width:  103   height:   72)
// Car: 44%	(left_x:  401   top_y:  183   width:   62   height:   44)
// Van: 92%	(left_x:  412   top_y:  165   width:   44   height:   41)
// Car: 96%	(left_x:  534   top_y:  179   width:   57   height:   46)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005074.png: Predicted in 15.133000 milli-seconds.
// Car: 99%	(left_x:  399   top_y:  188   width:   91   height:   54)
// Car: 79%	(left_x:  451   top_y:  189   width:   61   height:   39)
// Car: 92%	(left_x:  486   top_y:  183   width:   53   height:   35)
// Car: 98%	(left_x:  550   top_y:  178   width:   36   height:   23)
// Car: 96%	(left_x:  694   top_y:  178   width:   57   height:   42)
// Car: 98%	(left_x:  715   top_y:  182   width:   87   height:   53)
// Car: 100%	(left_x:  751   top_y:  181   width:  132   height:   85)
// Car: 89%	(left_x:  840   top_y:  179   width:  199   height:  149)
// Car: 94%	(left_x: 1013   top_y:  209   width:  236   height:  171)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005332.png: Predicted in 14.787000 milli-seconds.
// Car: 92%	(left_x:  151   top_y:  191   width:  134   height:   58)
// Car: 82%	(left_x:  618   top_y:  171   width:   35   height:   31)
// Car: 88%	(left_x:  658   top_y:  175   width:   36   height:   33)
// Car: 33%	(left_x:  667   top_y:  172   width:   34   height:   24)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005110.png: Predicted in 14.264000 milli-seconds.
// Car: 79%	(left_x:  550   top_y:  164   width:   25   height:   19)
// Pedestrian: 37%	(left_x:  625   top_y:  163   width:    7   height:   18)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007398.png: Predicted in 14.023000 milli-seconds.
// Car: 34%	(left_x:   12   top_y:  173   width:  105   height:  211)
// Car: 82%	(left_x:  183   top_y:  191   width:  235   height:  118)
// Car: 96%	(left_x:  515   top_y:  184   width:   62   height:   38)
// Car: 91%	(left_x:  634   top_y:  178   width:   37   height:   21)
// Cyclist: 70%	(left_x:  703   top_y:  174   width:   33   height:   64)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006736.png: Predicted in 15.059000 milli-seconds.
// Car: 97%	(left_x:  374   top_y:  184   width:   82   height:   51)
// Car: 96%	(left_x:  427   top_y:  178   width:   72   height:   45)
// Car: 81%	(left_x:  648   top_y:  174   width:   34   height:   25)
// Car: 95%	(left_x:  682   top_y:  172   width:   43   height:   34)
// Car: 45%	(left_x: 1168   top_y:  152   width:   66   height:   39)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005340.png: Predicted in 15.088000 milli-seconds.
// Car: 89%	(left_x:  581   top_y:  170   width:   46   height:   34)
// Car: 79%	(left_x:  636   top_y:  175   width:   38   height:   39)
// Car: 45%	(left_x:  924   top_y:  161   width:   76   height:   27)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006869.png: Predicted in 15.161000 milli-seconds.
// Car: 98%	(left_x:    1   top_y:  187   width:  269   height:  173)
// Car: 99%	(left_x:  350   top_y:  176   width:  125   height:   74)
// Car: 44%	(left_x:  414   top_y:  172   width:   76   height:   54)
// Car: 82%	(left_x:  471   top_y:  171   width:   57   height:   40)
// Car: 33%	(left_x:  805   top_y:  167   width:  145   height:   65)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005921.png: Predicted in 14.301000 milli-seconds.
// Car: 61%	(left_x:  387   top_y:  182   width:   32   height:   22)
// Van: 67%	(left_x:  415   top_y:  175   width:   30   height:   28)
// Truck: 99%	(left_x:  592   top_y:  160   width:   22   height:   33)
// Car: 100%	(left_x:  809   top_y:  179   width:  128   height:   52)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006842.png: Predicted in 13.537000 milli-seconds.
// Car: 91%	(left_x:  224   top_y:  183   width:   76   height:   27)
// Pedestrian: 62%	(left_x:  426   top_y:  174   width:   18   height:   50)
// Car: 71%	(left_x:  434   top_y:  178   width:   90   height:   35)
// Car: 54%	(left_x:  514   top_y:  174   width:   31   height:   22)
// Car: 84%	(left_x:  550   top_y:  174   width:   29   height:   19)
// Car: 42%	(left_x:  577   top_y:  174   width:   28   height:   18)
// Car: 99%	(left_x:  670   top_y:  171   width:   84   height:   27)
// Car: 100%	(left_x:  834   top_y:  178   width:  425   height:  203)
// Car: 89%	(left_x:  867   top_y:  170   width:   95   height:   24)
// Van: 42%	(left_x: 1158   top_y:  161   width:   73   height:   30)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005748.png: Predicted in 15.032000 milli-seconds.
// Car: 79%	(left_x:  108   top_y:  178   width:   46   height:   26)
// Car: 98%	(left_x:  324   top_y:  186   width:   90   height:   60)
// Car: 56%	(left_x:  357   top_y:  176   width:   38   height:   26)
// Car: 57%	(left_x:  388   top_y:  178   width:   47   height:   27)
// Car: 78%	(left_x:  429   top_y:  177   width:   39   height:   24)
// Car: 79%	(left_x:  477   top_y:  174   width:   27   height:   19)
// Car: 29%	(left_x:  499   top_y:  175   width:   26   height:   18)
// Van: 30%	(left_x:  533   top_y:  160   width:   24   height:   27)
// Car: 99%	(left_x:  594   top_y:  174   width:   50   height:   45)
// Car: 37%	(left_x:  659   top_y:  169   width:   64   height:   32)
// Van: 81%	(left_x:  665   top_y:  165   width:   77   height:   41)
// Car: 75%	(left_x:  681   top_y:  170   width:   88   height:   39)
// Car: 98%	(left_x:  713   top_y:  170   width:  141   height:   70)
// Car: 100%	(left_x:  777   top_y:  165   width:  201   height:  111)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// ...
// Car: 67%	(left_x:  209   top_y:  182   width:  177   height:   93)
// Car: 99%	(left_x:  304   top_y:  190   width:  192   height:  147)
// Car: 96%	(left_x:  546   top_y:  183   width:   54   height:   34)
// Car: 39%	(left_x:  632   top_y:  183   width:   62   height:   42)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005198.png: Predicted in 14.651000 milli-seconds.
// Car: 85%	(left_x:   -1   top_y:  153   width:  213   height:  182)
// Car: 97%	(left_x:  277   top_y:  182   width:  157   height:   56)
// Car: 33%	(left_x:  395   top_y:  183   width:   86   height:   32)
// Cyclist: 89%	(left_x:  433   top_y:  179   width:   36   height:   93)
// Car: 68%	(left_x:  444   top_y:  181   width:   63   height:   27)
// Van: 95%	(left_x:  604   top_y:  166   width:   17   height:   24)
// Car: 98%	(left_x:  612   top_y:  175   width:   33   height:   31)
// Car: 100%	(left_x:  628   top_y:  183   width:   62   height:   42)
// Car: 94%	(left_x:  801   top_y:  172   width:  292   height:  105)
// Car: 99%	(left_x:  972   top_y:  182   width:  274   height:  197)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006646.png: Predicted in 15.029000 milli-seconds.
// Car: 88%	(left_x:   11   top_y:  207   width:  321   height:  165)
// Car: 99%	(left_x:  320   top_y:  189   width:  177   height:  119)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007451.png: Predicted in 14.484000 milli-seconds.
// Car: 96%	(left_x:   -7   top_y:  166   width:  120   height:  118)
// Van: 72%	(left_x:  513   top_y:  174   width:   26   height:   21)
// Car: 98%	(left_x:  557   top_y:  173   width:  122   height:  104)
// Pedestrian: 73%	(left_x:  749   top_y:  165   width:   19   height:   58)
// Car: 92%	(left_x:  889   top_y:  138   width:  346   height:  225)
// Pedestrian: 25%	(left_x:  913   top_y:  167   width:   11   height:   38)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005196.png: Predicted in 14.193000 milli-seconds.
// Car: 50%	(left_x:  565   top_y:  179   width:   24   height:   20)
// Car: 59%	(left_x:  579   top_y:  178   width:   27   height:   22)
// Car: 96%	(left_x:  650   top_y:  178   width:   42   height:   35)
// Car: 87%	(left_x:  672   top_y:  178   width:   78   height:   62)
// Car: 93%	(left_x:  686   top_y:  185   width:  115   height:   79)
// Car: 100%	(left_x:  880   top_y:  168   width:  385   height:  201)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007118.png: Predicted in 15.130000 milli-seconds.
// Pedestrian: 69%	(left_x:  732   top_y:  166   width:   36   height:   86)
// Pedestrian: 33%	(left_x:  772   top_y:  165   width:   49   height:   92)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005506.png: Predicted in 15.072000 milli-seconds.
// Car: 87%	(left_x:  480   top_y:  177   width:   37   height:   22)
// Pedestrian: 33%	(left_x:  594   top_y:  171   width:    6   height:   26)
// Car: 98%	(left_x:  710   top_y:  175   width:   28   height:   22)
// Car: 58%	(left_x:  896   top_y:  165   width:   43   height:   18)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005016.png: Predicted in 15.051000 milli-seconds.
// Car: 96%	(left_x:   14   top_y:  196   width:  199   height:   85)
// Car: 40%	(left_x:  263   top_y:  189   width:  165   height:   93)
// Car: 95%	(left_x:  315   top_y:  185   width:  203   height:  109)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005347.png: Predicted in 14.879000 milli-seconds.
// Car: 99%	(left_x:  416   top_y:  162   width:   59   height:   47)
// Car: 66%	(left_x:  441   top_y:  158   width:   41   height:   34)
// Car: 65%	(left_x:  493   top_y:  147   width:   28   height:   21)
// Van: 92%	(left_x:  620   top_y:  110   width:  146   height:  100)
// Truck: 80%	(left_x:  815   top_y:   87   width:  370   height:  128)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007343.png: Predicted in 14.650000 milli-seconds.
// Van: 97%	(left_x:  777   top_y:  137   width:   95   height:   98)
// Car: 83%	(left_x: 1003   top_y:  184   width:  191   height:   89)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005278.png: Predicted in 14.023000 milli-seconds.
// Van: 93%	(left_x:  297   top_y:  120   width:  170   height:  149)
// Cyclist: 57%	(left_x:  672   top_y:  167   width:   34   height:   67)
// Pedestrian: 43%	(left_x: 1016   top_y:  165   width:   40   height:  100)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006788.png: Predicted in 15.113000 milli-seconds.
// Car: 98%	(left_x:   38   top_y:  191   width:  177   height:   76)
// Van: 91%	(left_x:  339   top_y:  157   width:   78   height:   73)
// Car: 99%	(left_x:  440   top_y:  181   width:  121   height:   59)
// Truck: 91%	(left_x:  499   top_y:  145   width:   61   height:   59)
// Car: 92%	(left_x:  668   top_y:  173   width:   29   height:   25)
// Van: 87%	(left_x:  730   top_y:  164   width:   26   height:   23)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006188.png: Predicted in 15.086000 milli-seconds.
// Car: 96%	(left_x:  355   top_y:  184   width:  113   height:   39)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005830.png: Predicted in 14.976000 milli-seconds.
// Car: 63%	(left_x:   -2   top_y:  198   width:   58   height:   42)
// Car: 89%	(left_x:   87   top_y:  193   width:   67   height:   35)
// Car: 96%	(left_x:  165   top_y:  190   width:   57   height:   30)
// Car: 46%	(left_x:  232   top_y:  188   width:   45   height:   27)
// Car: 57%	(left_x:  272   top_y:  186   width:   39   height:   25)
// Truck: 88%	(left_x:  578   top_y:  126   width:   65   height:   96)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005919.png: Predicted in 14.655000 milli-seconds.
// Car: 93%	(left_x:  217   top_y:  152   width:  282   height:  199)
// Car: 95%	(left_x:  382   top_y:  191   width:  132   height:   96)
// Car: 97%	(left_x:  512   top_y:  190   width:   50   height:   38)
// Car: 70%	(left_x:  658   top_y:  193   width:   43   height:   35)
// Car: 93%	(left_x:  682   top_y:  197   width:   55   height:   46)
// Car: 85%	(left_x:  730   top_y:  198   width:  100   height:   79)
// Car: 99%	(left_x:  750   top_y:  206   width:  169   height:  107)
// Car: 100%	(left_x:  886   top_y:  223   width:  361   height:  154)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005037.png: Predicted in 14.940000 milli-seconds.
// Pedestrian: 25%	(left_x:  438   top_y:  170   width:   15   height:   41)
// Pedestrian: 75%	(left_x:  481   top_y:  169   width:   24   height:   66)
// Car: 95%	(left_x:  579   top_y:  165   width:   40   height:   37)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005998.png: Predicted in 14.127000 milli-seconds.
// Car: 99%	(left_x:  158   top_y:  176   width:   75   height:   38)
// Car: 99%	(left_x:  398   top_y:  175   width:   94   height:   91)
// Truck: 51%	(left_x:  538   top_y:  152   width:   41   height:   53)
// Car: 50%	(left_x:  544   top_y:  178   width:   23   height:   21)
// Car: 97%	(left_x:  581   top_y:  177   width:   40   height:   38)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007110.png: Predicted in 15.122000 milli-seconds.
// Pedestrian: 52%	(left_x:   72   top_y:  158   width:   70   height:  146)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007034.png: Predicted in 14.947000 milli-seconds.
// Car: 88%	(left_x:  184   top_y:  218   width:  213   height:  134)
// Car: 99%	(left_x:  368   top_y:  186   width:  112   height:   86)
// Truck: 88%	(left_x:  502   top_y:  149   width:   65   height:   70)
// Pedestrian: 39%	(left_x:  595   top_y:  172   width:   13   height:   48)
// Car: 74%	(left_x:  607   top_y:  181   width:   42   height:   35)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005555.png: Predicted in 14.607000 milli-seconds.
// Tram: 67%	(left_x:   23   top_y:  131   width:  344   height:   99)
// Car: 99%	(left_x:  587   top_y:  175   width:   31   height:   27)
// Cyclist: 90%	(left_x:  680   top_y:  172   width:   16   height:   32)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007294.png: Predicted in 14.151000 milli-seconds.
// Car: 99%	(left_x:  408   top_y:  190   width:  107   height:   86)
// Car: 79%	(left_x:  538   top_y:  178   width:   35   height:   32)
// Van: 90%	(left_x:  647   top_y:  170   width:   47   height:   40)
// Van: 89%	(left_x:  656   top_y:  175   width:   55   height:   51)
// Car: 28%	(left_x:  671   top_y:  182   width:   68   height:   63)
// Car: 99%	(left_x:  688   top_y:  179   width:  110   height:   92)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005156.png: Predicted in 15.209000 milli-seconds.
// Car: 100%	(left_x:  130   top_y:  176   width:  291   height:  187)
// Car: 86%	(left_x:  340   top_y:  179   width:  124   height:   93)
// Car: 83%	(left_x:  421   top_y:  184   width:   73   height:   59)
// Car: 89%	(left_x:  474   top_y:  174   width:   50   height:   30)
// Car: 97%	(left_x:  679   top_y:  151   width:  224   height:  118)
// Car: 100%	(left_x:  786   top_y:  174   width:  347   height:  179)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007322.png: Predicted in 15.088000 milli-seconds.
// Car: 100%	(left_x:  619   top_y:  175   width:  213   height:   90)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007050.png: Predicted in 14.614000 milli-seconds.
// Car: 30%	(left_x:   -1   top_y:  197   width:   40   height:   45)
// Car: 47%	(left_x:    4   top_y:  184   width:   74   height:   50)
// Car: 96%	(left_x:   60   top_y:  186   width:   97   height:   39)
// Car: 94%	(left_x:  165   top_y:  184   width:   60   height:   30)
// Car: 75%	(left_x:  242   top_y:  180   width:   53   height:   29)
// Car: 35%	(left_x:  276   top_y:  179   width:   45   height:   24)
// Car: 27%	(left_x:  314   top_y:  178   width:   40   height:   23)
// Car: 81%	(left_x:  357   top_y:  176   width:   36   height:   22)
// Truck: 97%	(left_x:  625   top_y:  125   width:   58   height:   82)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006132.png: Predicted in 14.887000 milli-seconds.
// Car: 98%	(left_x:  229   top_y:  185   width:  170   height:   57)
// Car: 85%	(left_x:  510   top_y:  178   width:   44   height:   17)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007390.png: Predicted in 15.054000 milli-seconds.
// Car: 82%	(left_x:   -2   top_y:  173   width:  120   height:   72)
// Car: 88%	(left_x:  115   top_y:  182   width:   94   height:   48)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007460.png: Predicted in 15.071000 milli-seconds.
// Car: 100%	(left_x:   -3   top_y:  195   width:  340   height:   92)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007440.png: Predicted in 15.003000 milli-seconds.
// Car: 92%	(left_x:    6   top_y:  211   width:   73   height:   37)
// Car: 97%	(left_x:   78   top_y:  206   width:   96   height:   36)
// Car: 28%	(left_x:  122   top_y:  205   width:   99   height:   37)
// Car: 94%	(left_x:  397   top_y:  193   width:   65   height:   46)
// Car: 81%	(left_x:  444   top_y:  191   width:   54   height:   36)
// Car: 67%	(left_x:  478   top_y:  183   width:   47   height:   32)
// Car: 98%	(left_x:  647   top_y:  175   width:   53   height:   42)
// Van: 99%	(left_x: 1017   top_y:  137   width:   91   height:   38)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/007278.png: Predicted in 15.326000 milli-seconds.
// Pedestrian: 67%	(left_x:  494   top_y:  161   width:   56   height:  141)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006952.png: Predicted in 15.218000 milli-seconds.
// Car: 26%	(left_x:   -1   top_y:  183   width:  118   height:   52)
// Car: 89%	(left_x:   14   top_y:  196   width:  196   height:  115)
// Car: 100%	(left_x:   15   top_y:  203   width:  355   height:  173)
// Car: 49%	(left_x:  263   top_y:  178   width:   66   height:   36)
// Car: 97%	(left_x:  274   top_y:  183   width:  137   height:   73)
// Car: 89%	(left_x:  344   top_y:  178   width:  112   height:   62)
// Car: 80%	(left_x:  410   top_y:  178   width:   75   height:   41)
// Car: 44%	(left_x:  453   top_y:  179   width:   70   height:   33)
// Car: 81%	(left_x:  477   top_y:  173   width:   56   height:   33)
// Car: 99%	(left_x:  559   top_y:  178   width:   60   height:   43)
// Car: 30%	(left_x:  590   top_y:  175   width:   38   height:   27)
// Truck: 46%	(left_x:  662   top_y:   95   width:  109   height:  143)
// Car: 99%	(left_x:  689   top_y:  176   width:   87   height:   77)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006980.png: Predicted in 15.100000 milli-seconds.
// Cyclist: 55%	(left_x:  635   top_y:  178   width:   87   height:  171)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005003.png: Predicted in 14.901000 milli-seconds.
// Car: 72%	(left_x:  575   top_y:  177   width:   21   height:   22)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/006694.png: Predicted in 14.459000 milli-seconds.
// Car: 100%	(left_x:  277   top_y:  177   width:  186   height:  135)
// Truck: 83%	(left_x:  446   top_y:  142   width:   91   height:   76)
// Van: 94%	(left_x:  618   top_y:  166   width:   31   height:   29)
// Car: 97%	(left_x:  660   top_y:  176   width:   67   height:   40)
// Car: 99%	(left_x:  732   top_y:  171   width:  160   height:  118)
// Car: 100%	(left_x:  836   top_y:  165   width:  328   height:  193)
// Enter Image Path:  Detection layer: 82 - type = 28
//  Detection layer: 94 - type = 28
//  Detection layer: 106 - type = 28
// data/kitti_test/005990.png: Predicted in 14.243000 milli-seconds.
// Car: 63%	(left_x:    4   top_y:  210   width:  214   height:  157)
// Car: 80%	(left_x:  525   top_y:  183   width:   28   height:   22)
// Enter Image Path:

// %% [markdown]
// ## Modifications to fit Darknet in NVBitFI framework

// %% [markdown]
// #### The notes of patching Darknet is lost, I will go through the steps again and finish this section
